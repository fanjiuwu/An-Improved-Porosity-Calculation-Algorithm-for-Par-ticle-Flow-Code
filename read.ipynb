# %%
import numpy as np

#loaded_data = np.loadtxt('porosity.txt', dtype=float)
loaded_data = np.loadtxt('porosity-centroid.txt', dtype=float)

print(loaded_data)


import numpy as np
import matplotlib.pyplot as plt
 
# 创建一个numpy数组
data = np.random.randn(1000)
 
# 绘制直方图
plt.hist(loaded_data, bins=100, color='green', edgecolor='k')
 
# 设置标题和轴标签
plt.title('Histogram of Porosity')
plt.xlabel('Value')
plt.ylabel('Frequency')
 
# 显示图形
plt.show()
# Out:
# [0.86910031 0.60730092 0.80365046 ... 0.80365046 0.93455015 1.        ]

# %%
x1=[]
x=np.array(x1)
np.append(x,9)
print(x)
# Out:
# []
